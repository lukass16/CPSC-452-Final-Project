# %%
import matplotlib.pyplot as plt

# recovered from training run of model on HPC (see output_vae_simple.ipynb)
losses = [0.0031,
    0.0017,
    0.0013,
    0.0011,
    0.0015,
    0.0046,
    0.0016,
    0.0016,
    0.0016,
    0.0023,
    0.0019,
    0.0020,
    0.0013,
    0.0014,
    0.0045,
    0.0027,
    0.0011,
    0.0012,
    0.0023,
    0.0014,
    0.0019,
    0.0021,
    0.0015,
    0.0020,
    0.0009,
    0.0055,
    0.0010,
    0.0022,
    0.0009,
    0.0011,
    0.0024,
    0.0014,
    0.0019,
    0.0022,
    0.0014,
    0.0033,
    0.0013,
    0.0016, 
    0.0018, 
    0.0019,
    0.0028,
    0.0010,
    0.0016,
    0.0015,
    0.0019,
    0.0018,
    0.0035,
    0.0016,
    0.0018,
    0.0042,
    0.0011,
    0.0013,
    0.0008,
    0.0010,
    0.0010,
    0.0010,
    0.0082,
    0.0021,
    0.0012,
    0.0027,
     0.0027,
     0.0012,
     0.0014,
     0.0009,
     0.0020,
     0.0010,
     0.0008,
     0.0017,
     0.0019,
     0.0017,
     0.0016,
     0.0013, 0.0008, 0.0013, 0.0010, 0.0015, 0.0007, 0.0069, 0.0245, 0.0009, 0.0010, 0.0011, 0.0016, 0.0011, 0.0010, 0.0016, 0.0009, 0.0011, 0.0014, 0.0033, 0.0017, 0.0009]

# also recovered from output_vae_simple.ipynb
val_losses = [0.0033, 0.0011, 0.0027, 0.0008]

epochs = range(1, len(losses) + 1)
val_epochs   = [20, 40, 60, 80]


plt.figure(figsize=(8, 5))
plt.plot(epochs, losses, marker='o', linestyle='-', linewidth=2, label='Training Loss')
plt.plot(val_epochs,   val_losses, marker='s', linestyle='--', linewidth=2, label='Val Loss')
plt.title('Training Loss by Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()      # <— this adds the key
plt.tight_layout()
plt.show()
