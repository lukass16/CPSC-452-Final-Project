# %%
import matplotlib.pyplot as plt

# recovered from training run of model on HPC (see output_vae_simple.ipynb and loss_log.txt)
losses = [
    0.0221, 0.0034, 0.0028, 0.0025, 0.0023, 0.0023, 0.0026, 0.0028, 0.0023, 0.0025,
    0.0026, 0.0025, 0.0023, 0.0023, 0.0024, 0.0056, 0.0025, 0.0022, 0.0022, 0.0027,
    0.0023, 0.0024, 0.0023, 0.0022, 0.0024, 0.0024, 0.0023, 0.0023, 0.0022, 0.0022,
    0.0023, 0.0026, 0.0022, 0.0023, 0.0022, 0.0022, 0.0022, 0.0022, 0.0023, 0.0028,
    0.0021, 0.0021, 0.0022, 0.0020, 0.0021, 0.0023, 0.0022, 0.0021, 0.0021, 0.0021,
    0.0021, 0.0020, 0.0026, 0.0021, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020,
    0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0019, 0.0019, 0.0019,
    0.0019, 0.0019, 0.0018, 0.0020, 0.0018, 0.0019, 0.0019, 0.0018, 0.0018, 0.0019,
    0.0018, 0.0020, 0.0018, 0.0019, 0.0019, 0.0019, 0.0018, 0.0018, 0.0018, 0.0018,
    0.0018, 0.0019, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0017,
    0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0017, 0.0018, 0.0018, 0.0018, 0.0017,
    0.0017, 0.0017, 0.0018, 0.0019, 0.0017, 0.0017, 0.0017, 0.0017, 0.0018, 0.0018,
    0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0018, 0.0018, 0.0017, 0.0018, 0.0017,
    0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0018, 0.0017,
    0.0017
]

# also recovered from output_vae_simple.ipynb
val_losses = [0.0033, 0.0011, 0.0027, 0.0008]

epochs = range(1, len(losses) + 1)


plt.figure(figsize=(8, 5))
plt.plot(epochs, losses, marker='o', linestyle='-', linewidth=2, label='Training Loss')
plt.title('Training Loss by Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()
plt.show()
